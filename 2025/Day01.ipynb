# %%
with open("data/day01.txt") as f:
    file = f.read().split()


test_file = ["L68", "L30", "R48", "L5", "R60", "L55", "L1", "L99", "R14", "L82"]

MAX_DIAL_V = 100
DIAL_V = 50
COUNT_0 = 0

for instruction in file:
    rotation, scalar = -1 if instruction[0] == "L" else 1, int(instruction[1:])
    DIAL_V += rotation * scalar 
    if DIAL_V % MAX_DIAL_V == 0:
        COUNT_0 += 1
    
    DIAL_V = DIAL_V % MAX_DIAL_V

print(COUNT_0)
# Out:
# 1034

# %%
test_file = ["L50"] + ["R50"] + ["L68", "L30", "R48", "L5", "R60", "L55", "L1", "L99", "R14", "L82"]
# 7
MAX_DIAL_V = 100
DIAL_V = 50
COUNT_0 = 0

for instruction in file:
    # Calculates how many times we cross through 100 divisible values
    rotation, scalar = -1 if instruction[0] == "L" else 1, int(instruction[1:])

    # Ooga Booga solution xD
    for _ in range(scalar):
        DIAL_V += 1 * rotation
        if DIAL_V % 100 == 0:
            COUNT_0 += 1


print(COUNT_0) # 6166.0
# Out:
# 6166
